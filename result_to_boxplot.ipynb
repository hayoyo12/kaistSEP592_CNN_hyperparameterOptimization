# %%
import csv, re
import matplotlib.pyplot as plt
from google.colab import drive
import numpy as np
import pandas as pd
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv(open('/content/drive/My Drive/SEP592_project/resultboxplot.csv'))
df.boxplot(by='rate', column=['bitInversionM'], grid=False)
plt.title('Bit Inversion Mutation')
plt.suptitle('')
plt.show()

# %%
df.boxplot(by='rate', column=['scrambleM'], grid=False)
plt.title('Scramble Mutation')
plt.suptitle('')
plt.show()

# %%
df.boxplot(by=['rate'], column=['inversionM'], grid=False)
plt.title('Inversion Mutation')
plt.suptitle('')
plt.show()

# %%
df.boxplot(by=['type'], column=['crossover'], grid=False)
plt.title('Three different Crossover operators')
plt.suptitle('')
plt.show()
